# %%
import numpy as np
import load

# %%
load.gen_heatmap_dataset(dest='../data/hm30rad/')
# Out:
# tomo_003acc heatmap empty
# tomo_003acc saved
# tomo_00e047 heatmap genned
# tomo_00e047 saved
# tomo_00e463 heatmap genned
# tomo_00e463 saved
# tomo_01a877 heatmap genned
# tomo_01a877 saved
# tomo_02862f heatmap genned
# tomo_02862f saved
# tomo_0308c5 heatmap empty
# tomo_0308c5 saved
# tomo_0333fa heatmap empty
# tomo_0333fa saved
# tomo_033ebe heatmap genned
# tomo_033ebe saved
# tomo_03437b heatmap genned
# tomo_03437b saved
# tomo_0363f2 heatmap genned
# tomo_0363f2 saved
# tomo_040b80 heatmap empty
# tomo_040b80 saved
# tomo_049310 heatmap empty
# tomo_049310 saved
# tomo_04d42b heatmap empty
# tomo_04d42b saved
# tomo_05b39c heatmap empty
# tomo_05b39c saved
# tomo_05df8a heatmap genned
# tomo_05df8a saved
# tomo_05f919 heatmap genned
# tomo_05f919 saved
# tomo_066095 heatmap empty
# tomo_066095 saved
# tomo_06e11e heatmap empty
# tomo_06e11e saved
# tomo_072a16 heatmap empty
# tomo_072a16 saved
# tomo_081a2d heatmap genned
# tomo_081a2d saved
# tomo_08446f heatmap genned
# ...
